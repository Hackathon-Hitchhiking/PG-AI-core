# %%
# !pip install aspose.slides python-pptx

# %%
import os
import json
from pptx import  PPTXHandler
if __name__ == "__main__":
    generate_template("template.json")
    pipeline = PPTXHandler(template_json_path="template.json")

    try:
        pipeline.parse_presentation("test.pptx", output_image_dir="extracted_images")
        
        # The content now includes images automatically extracted from the input presentation.
        
        pipeline.create_presentation_from_template("output_presentation.pptx")
        print("Presentation successfully created!")
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Presentation successfully created!
